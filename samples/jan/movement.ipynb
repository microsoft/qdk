# %%
from qdk.widgets import Atoms

# %%
layout = {
  "cols": 40,
  "zones": [
    { "title": "Storage Zone", "rows": 25, "kind": "register" },
    { "title": "Interaction Zone", "rows": 2, "kind": "interaction" },
    { "title": "Measurement Zone", "rows": 2, "kind": "measurement" },
  ],
}

trace = {
  "steps": [
    { "id": 0, "ops": ["move(17, 0) 0", "move(17, 1) 7"] },
  ]
}

# %%
Atoms(machine_layout=layout, trace_data=trace)
