# %%
from pathlib import Path

src = Path("benzene_diradical_injected_rotation_measurement_circuit_0.qasm").read_text()

# %%
from qdk import init, TargetProfile, BitFlipNoise
from qdk.openqasm import compile

init(target_profile=TargetProfile.Base)
qir = compile(src)

# %% [markdown]
# ## TODO
#
# Try to implement the below noise model
#
# ```txt
# name:  injected rotations
# description:  Noise model for a QEC device with injected rotations
# errors:
#   cx:
#     type:  depolarizing_error
#     num_qubits:  2
#     rate:  0.0005
#   cnot:
#     type:  depolarizing_error
#     num_qubits:  2
#     rate:  0.0005
#   cz:
#     type:  depolarizing_error
#     num_qubits:  2
#     rate:  0.0005
#   x:
#     type:  depolarizing_error
#     num_qubits:  1
#     rate:  0.0  # Free because of Pauli frame tracking
#   y:
#     type:  depolarizing_error
#     num_qubits:  1
#     rate:  0.0  # Free because of Pauli frame tracking
#   z:
#     type:  depolarizing_error
#     num_qubits:  1
#     rate:  0.0  # Free because of Pauli frame tracking
#   id:
#     type:  depolarizing_error
#     num_qubits:  1
#     rate:  0.0  # Seems like it should be free
#   h:
#     type:  depolarizing_error
#     num_qubits:  1
#     rate:  0.0005
#   s:  # sz
#     type:  depolarizing_error
#     num_qubits:  1
#     rate:  0.0005
#   sdg:  # sz adjoint
#     type:  depolarizing_error
#     num_qubits:  1
#     rate:  0.0005
#   rz:
#     type:  depolarizing_error
#     num_qubits:  1
#     rate:  0.007
#   measure:
#     type:  depolarizing_error
#     num_qubits:  1
#     rate:  0.0002
#   barrier:
#     type:  depolarizing_error
#     num_qubits:  1
#     rate:  0.0
# ```

# %%
from qsharp._simulation import run_qir_gpu
from qdk.widgets import Histogram

output = run_qir_gpu(str(qir), shots=3, noise=BitFlipNoise(0.01), seed=None)
Histogram(output)
